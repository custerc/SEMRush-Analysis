# %%
import pandas as pd

data = pd.read_csv('rankings-sept19.csv')
data.head()
# Out:
#              Keyword                             Tags  \
# 0    python tutorial     intent_keywords|python|tier2
# 1       python class            intent_keywords|tier2
# 2     python classes            intent_keywords|tier2
# 3       git tutorial      intent_keywords|tier2|tier3
# 4  sql certification  intent_keywords|sql|tier2|tier3
#
#   *.dataquest.io/*_20190914 *.dataquest.io/*_20190914_type  \
# 0                        34                        organic
# 1                         -                        organic
# 2                         -                        organic
# 3                        60                        organic
# 4                         -                        organic
#
#                    *.dataquest.io/*_20190914_landing  \
# 0  https://www.dataquest.io/blog/learn-python-the...
# 1                                                NaN
# 2                                                NaN
# 3  https://www.dataquest.io/blog/tutorial-introdu...
# ...

# %%
data_bool = data[]
